# %% [markdown]
# # QR Codes with Python by Kamaraj Rangaswamy

# %% [markdown]
# # QR Codes with Python
#
# QR is short for Quick Response, and they are named so because they can be read quickly by a cell phone. They are used to take information from transitory media and put it on your cell phone.
#
# # What is a QR code?
#
# A QR code is a type of barcode that can be read easily by a digital device and which stores information as a series of pixels in a square-shaped grid. QR codes are frequently used to track information about products in a supply chain and because many smartphones have built-in QR readers, they are often used in marketing and advertising campaigns. More recently, they have played a key role in helping to trace coronavirus exposure and slow the spread of the virus
#
# # QR Codes with Python: Tutorial
#
# To generate QR Codes with Python you need to install only one Python library for this task:
#
#
# *   pip install pyqrcode
#
# # How to create a QR Code with Python programming language

# %%
pip install pyqrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36221 sha256=f7033885d2add36266c326b39b05917fc2541cc5514821733fcb6c0681dc7fd6
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# ...

# %%
import pyqrcode
from pyqrcode import QRCode

# String which represent the QR code
A = "https://www.indiatoday.in/"

# Generate QR code
url = pyqrcode.create(A)

# Create and save the png file naming "indiatoday"
url.svg("indiatoday.svg", scale = 8)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
